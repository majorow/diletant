# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/drive/MyDrive/usdrub.csv', parse_dates=['date'])

# %%
df = df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7640 entries, 0 to 7755
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    7640 non-null   datetime64[ns]
#  1   open    7640 non-null   float64
#  2   high    7640 non-null   float64
#  3   low     7640 non-null   float64
#  4   close   7640 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 358.1 KB

# %%
df = df.groupby('date').first()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5323 entries, 1999-06-29 to 2021-12-03
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    5323 non-null   float64
#  1   high    5323 non-null   float64
#  2   low     5323 non-null   float64
#  3   close   5323 non-null   float64
# dtypes: float64(4)
# memory usage: 207.9 KB

# %%
import matplotlib.pyplot as plt
gr = df.plot(figsize=(24, 6))

# %%
df.corr()
# Out:
#            open      high       low     close
# open   1.000000  0.999749  0.999876  0.999785
# high   0.999749  1.000000  0.999602  0.999868
# low    0.999876  0.999602  1.000000  0.999829
# close  0.999785  0.999868  0.999829  1.000000

# %%
df.to_csv('/content/drive/MyDrive/usdrub.csv')
